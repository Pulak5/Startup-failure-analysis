# %%
import numpy as np
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url="https://www.failory.com/failures"
header={"User-Agent":"Mozilla/5.0"}

response=requests.get(url,headers=header)
soup=BeautifulSoup(response.content,"html.parser")

# %%
links=soup.find_all("a")
urls=[]
for link in links:
    urls.append(link.get("href"))
    print(link.get("href"))
# Out:
# https://failory.podia.com/pre-sales
# /
# /interviews
# /blog
# /graveyard
# /products
# /subscribe
# #
# /startups/web-app-failures
# /startups/denmark-failures
# /startups/bulgaria-failures
# /startups/competition-failures
# /startups/london-failures
# /startups/agency-failures
# /startups/streaming-failures
# /startups/germany-failures
# /startups/fashion-failures
# /startups/australia-failures
# /startups/canada-failures
# /startups/lack-of-experience-failures
# /startups/bad-market-fit-failures
# /startups/spain-failures
# /startups/san-francisco-failures
# /startups/los-angeles-failures
# /startups/education-failures
# /startups/health-failures
# /startups/bad-timing-failures
# /startups/b2b2c-failures
# /startups/bad-marketing-failures
# /startups/app-failures
# /startups/artificial-intelligence-failures
# /startups/b2c-failures
# /startups/crypto-failures
# ?e93210f1_page=2
# /startups/australia-failures
# /startups/belgium-failures
# /startups/bulgaria-failures
# /startups/canada-failures
# /startups/denmark-failures
# /startups/germany-failures
# /startups/india-failures
# /startups/indonesia-failures
# /startups/mexico-failures
# /startups/russia-failures
# /startups/spain-failures
# /startups/sweden-failures
# /startups/united-kingdom-failures
# /startups/united-states-failures
# /startups/berlin-failures
# /startups/london-failures
# /startups/los-angeles-failures
# /startups/new-york-failures
# /startups/san-francisco-failures
# /startups/silicon-valley-failures
# /startups/sydney-failures
# /startups/toronto-failures
# /startups/analytics-failures
# /startups/artificial-intelligence-failures
# /startups/blockchain-failures
# /startups/community-failures
# /startups/crypto-failures
# /startups/design-failures
# /startups/e-commerce-failures
# /startups/edtech-failures
# /startups/education-failures
# /startups/entertainment-failures
# /startups/fashion-failures
# /startups/fintech-failures
# /startups/food-beverage-failures
# /startups/foodtech-failures
# /startups/health-failures
# /startups/marketing-failures
# /startups/music-failures
# /startups/no-code-failures
# /startups/productivity-failures
# /startups/robot-failures
# /startups/social-media-failures
# /startups/software-hardware-failures
# /startups/sports-failures
# /startups/streaming-failures
# /startups/transportation-failures
# /startups/travel-failures
# /startups/agency-failures
# /startups/app-failures
# /startups/b2b2c-failures
# /startups/b2b-failures
# /startups/b2c-failures
# /startups/blog-failures
# /startups/courses-failures
# /startups/marketplace-failures
# /startups/saas-failures
# /startups/services-failures
# /startups/subscription-failures
# /startups/web-app-failures
# /startups/bad-business-model-failures
# /startups/bad-management-failures
# /startups/bad-market-fit-failures
# /startups/bad-marketing-failures
# /startups/bad-timing-failures
# /startups/competition-failures
# /startups/depending-on-others-failures
# /startups/lack-of-experience-failures
# /startups/lack-of-focus-failures
# /startups/lack-of-funds-failures
# /startups/legal-challenges-failures
# /startups/mismanagement-of-funds-failures
# /startups/no-market-need-failures
# /startups/no-pivoting-failures
# /startups/poor-product-failures
# /interviews
# /blog
# /podcast
# /cemetery
# /google
# /amazon
# /tools
# /products
# /pitch-deck
# /unicorns
# /failures
# /startups
# /accelerators-incubators
# /vc-firms
# https://www.passionfroot.me/failory
# https://calendly.com/cerdeira/60-min-strategy-call
# /contribute
# /about
# /subscribe
# /privacy
# https://twitter.com/hellofailory
# https://twitter.com/nicocerdeira
# mailto:nico@failory.com

# %%
links=urls[8:len(urls)-23]
links
# Out:
# ['/startups/web-app-failures',
#  '/startups/denmark-failures',
#  '/startups/bulgaria-failures',
#  '/startups/competition-failures',
#  '/startups/london-failures',
#  '/startups/agency-failures',
#  '/startups/streaming-failures',
#  '/startups/germany-failures',
#  '/startups/fashion-failures',
#  '/startups/australia-failures',
#  '/startups/canada-failures',
#  '/startups/lack-of-experience-failures',
#  '/startups/bad-market-fit-failures',
#  '/startups/spain-failures',
#  '/startups/san-francisco-failures',
#  '/startups/los-angeles-failures',
#  '/startups/education-failures',
#  '/startups/health-failures',
#  '/startups/bad-timing-failures',
#  '/startups/b2b2c-failures',
#  '/startups/bad-marketing-failures',
#  '/startups/app-failures',
#  '/startups/artificial-intelligence-failures',
#  '/startups/b2c-failures',
#  '/startups/crypto-failures',
#  '?e93210f1_page=2',
#  '/startups/australia-failures',
#  '/startups/belgium-failures',
#  '/startups/bulgaria-failures',
#  '/startups/canada-failures',
#  '/startups/denmark-failures',
#  '/startups/germany-failures',
#  '/startups/india-failures',
#  '/startups/indonesia-failures',
#  '/startups/mexico-failures',
#  '/startups/russia-failures',
#  '/startups/spain-failures',
#  '/startups/sweden-failures',
#  '/startups/united-kingdom-failures',
#  '/startups/united-states-failures',
#  '/startups/berlin-failures',
#  '/startups/london-failures',
#  '/startups/los-angeles-failures',
#  '/startups/new-york-failures',
#  '/startups/san-francisco-failures',
#  '/startups/silicon-valley-failures',
#  '/startups/sydney-failures',
#  '/startups/toronto-failures',
#  '/startups/analytics-failures',
#  '/startups/artificial-intelligence-failures',
#  '/startups/blockchain-failures',
#  '/startups/community-failures',
#  '/startups/crypto-failures',
#  '/startups/design-failures',
#  '/startups/e-commerce-failures',
#  '/startups/edtech-failures',
#  '/startups/education-failures',
#  '/startups/entertainment-failures',
#  '/startups/fashion-failures',
#  '/startups/fintech-failures',
#  '/startups/food-beverage-failures',
#  '/startups/foodtech-failures',
#  '/startups/health-failures',
#  '/startups/marketing-failures',
#  '/startups/music-failures',
#  '/startups/no-code-failures',
#  '/startups/productivity-failures',
#  '/startups/robot-failures',
#  '/startups/social-media-failures',
#  '/startups/software-hardware-failures',
#  '/startups/sports-failures',
#  '/startups/streaming-failures',
#  '/startups/transportation-failures',
#  '/startups/travel-failures',
#  '/startups/agency-failures',
#  '/startups/app-failures',
#  '/startups/b2b2c-failures',
#  '/startups/b2b-failures',
#  '/startups/b2c-failures',
#  '/startups/blog-failures',
#  '/startups/courses-failures',
#  '/startups/marketplace-failures',
#  '/startups/saas-failures',
#  '/startups/services-failures',
#  '/startups/subscription-failures',
#  '/startups/web-app-failures',
#  '/startups/bad-business-model-failures',
#  '/startups/bad-management-failures',
#  '/startups/bad-market-fit-failures',
#  '/startups/bad-marketing-failures',
#  '/startups/bad-timing-failures',
#  '/startups/competition-failures',
#  '/startups/depending-on-others-failures',
#  '/startups/lack-of-experience-failures',
#  '/startups/lack-of-focus-failures',
#  '/startups/lack-of-funds-failures',
#  '/startups/legal-challenges-failures',
#  '/startups/mismanagement-of-funds-failures',
#  '/startups/no-market-need-failures',
#  '/startups/no-pivoting-failures',
#  '/startups/poor-product-failures']

# %%
base_url="https://www.failory.com"

# %%
def get_data(base_url,ts,te,list,records):
    for c in list:
        url=base_url+ts+c+te
        time.sleep(1)
        res=requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        soup=BeautifulSoup(res.content,"html.parser")
        blocks=soup.find_all("div",class_="listicle-startup-collection-item")
        print(len(blocks))
        for b in blocks:
            text=b.get_text(separator="|",strip=True)
            parts=text.split("|")
            data = {
                'Startup': parts[0],
                'Description': parts[1]
            }

            for i in range(len(parts)-1):
                key = parts[i].strip().lower()

                if 'founder' in key:
                    data['Founders'] = parts[i+1]

                elif key == 'country:':
                    data['Country'] = parts[i+1]

                elif key == 'industry:':
                    data['Industry'] = parts[i+1]

                elif key == 'started in:':
                    data['Started in'] = parts[i+1]

                elif key == 'closed in:':
                    data['Closed in'] = parts[i+1]

                elif 'employees' in key:
                    data['Employees'] = parts[i+1]

                elif key == 'funding amount:':
                    data['Funding Amount'] = parts[i+1]

                elif 'specific' in key:
                    data['Failure Cause'] = parts[i+1]

            records.append(data)

# %%
countries=["germany","india","belgium","russia","bulgaria","spain","sweden","canada"]
categories=["fashion","education","artificial-intelligence","e-commerce","crypto","foodtech","depending-on-others","productivity","health","sports","transportation"]
records=[]
ts="/startups/"
te="-failures"
get_data(base_url,ts,te,countries,records)
print(len(records))
# Out:
# 7
# 17
# 3
# 3
# 3
# 3
# 3
# 8
# 47

# %%
get_data(base_url,ts,te,categories,records)
# Out:
# 5
# 16
# 7
# 31
# 3
# 16
# 11
# 17
# 11
# 6
# 17

# %%
df=pd.DataFrame(records)
df['Employees'] = df['Employees'].astype(str)

# %%
df.head()
# Out:
#       Startup                                        Description  \
# 0  Auctionata  Auctionata was an online auction platform for ...
# 1       Moped  Moped was a free social app. It had not enough...
# 2        ABBY  ABBY was a documentation service for A/B tests...
# 3        Flux  Flux was a modular multi messaging client. The...
# 4    Gameslog  Gameslog was a gaming site monetized with affi...
#
#                                             Founders  Country  \
# 0  Alexander Gilkes, Alexander Zacke, Georg Unter...  Germany
# 1                                   Schuyler Deerman  Germany
# 2                                   Andy Goldschmidt  Germany
# 3                                       Jan Johannes  Germany
# 4                                Michael Hebenstreit  Germany
#
#               Industry Started in Closed in Employees Funding Amount  \
# 0           e-Commerce       2012      2017   250-500         > $50M
# 1         Social Media       1998      2014     10-50       $1M-$10M
# 2            Analytics       2015      2016       nan             $0
# 3  Software & Hardware       2011      2016       nan        < $100K
# 4        Entertainment       2013      2014       nan             $0
#
#       Failure Cause
# 0  Legal Challenges
# 1    No Market Need
# 2    No Market Need
# 3    Bad Management
# 4       Competition

# %%
import csv

df.to_csv("startup_failures.csv",index=False,quoting=csv.QUOTE_ALL)
